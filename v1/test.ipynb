# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = '/Users/zelun/Downloads/GLODAPv2.2023_Merged_Master_File.csv'
ds = pd.read_csv(file)
# Out:
# /var/folders/x4/92sj1jws22z1d_vn3_99b3c00000gn/T/ipykernel_37848/2830747276.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds = pd.read_csv(file)

# %%
ds
# Out:
#            G2expocode  G2cruise  G2station  G2region  G2cast  G2year  G2month  \
# 0        06AQ19840719       1.0      319.0       4.0     1.0  1984.0      7.0
# 1        06AQ19840719       1.0      319.0       4.0     1.0  1984.0      7.0
# 2        06AQ19840719       1.0      319.0       4.0     1.0  1984.0      7.0
# 3        06AQ19840719       1.0      319.0       4.0     1.0  1984.0      7.0
# 4        06AQ19840719       1.0      319.0       4.0     1.0  1984.0      7.0
# ...               ...       ...        ...       ...     ...     ...      ...
# 1402824  77DN20210725    5023.0       58.0       4.0    18.0  2021.0      9.0
# 1402825  77DN20210725    5023.0       58.0       4.0    18.0  2021.0      9.0
# 1402826  77DN20210725    5023.0       58.0       4.0    18.0  2021.0      9.0
# 1402827  77DN20210725    5023.0       58.0       4.0    18.0  2021.0      9.0
# 1402828  77DN20210725    5023.0       58.0       4.0    18.0  2021.0      9.0
#
# ...

# %%
DOC = ds.G2doc.values
DOC[DOC<0] = np.nan
year = ds.G2year.values
month = ds.G2month.values
day = ds.G2day.values
lat = ds.G2latitude.values
lon = ds.G2longitude.values

# %%
ivalid = ~np.isnan(DOC * year)
np.sum(ivalid)
# Out:
# 51.057201044650874

# %%
plt.hist(DOC[ivalid],bins=1000)
plt.xlim([0,250])
# Out:
# (0.0, 250.0)

# %%
plt.scatter(lon[ivalid],lat[ivalid],c=DOC[ivalid],s=10,clim=[0,100],cmap=plt.get_cmap('jet',256))
plt.colorbar()
